# %% [markdown]
# # Loading gct file using CePa library

# %%
library(CePa)

# %%
data=read.gct("new.gct")

# %%
head(data)
# Out:
#                     aab1.Primary.solid.Tumor
# participant_id      aab1
# sample_type         Primary solid Tumor
# mRNAseq_cluster     1
# bcr_patient_barcode tcga-2j-aab1
# bcr_patient_uuid    75119d1a-93e5-4ae7-9d60-69ee929a0772
# vital_status        dead
#                     aab4.Primary.solid.Tumor
# participant_id      aab4
# sample_type         Primary solid Tumor
# mRNAseq_cluster     2
# bcr_patient_barcode tcga-2j-aab4
# bcr_patient_uuid    33833131-1482-42d5-9cf5-01cade540234
# vital_status        alive
#                     aab6.Primary.solid.Tumor
# participant_id      aab6
# sample_type         Primary solid Tumor
# mRNAseq_cluster     3
# bcr_patient_barcode tcga-2j-aab6
# bcr_patient_uuid    70797499-16e6-48cc-8ae4-1e692713dad3
# vital_status        dead
#                     aab8.Primary.solid.Tumor
# participant_id      aab8
# sample_type         Primary solid Tumor
# mRNAseq_cluster     1
# bcr_patient_barcode tcga-2j-aab8
# ...

# %%
rownames(data)
# Out:
#     [1] "participant_id"
#     [2] "sample_type"
#     [3] "mRNAseq_cluster"
#     [4] "bcr_patient_barcode"
#     [5] "bcr_patient_uuid"
#     [6] "vital_status"
#     [7] "days_to_death"
#     [8] "days_to_last_followup"
#     [9] "additional_studies"
#    [10] "adenocarcinoma_invasion"
#    [11] "age_at_initial_pathologic_diagnosis"
#    [12] "alcohol_history_documented"
#    [13] "alcoholic_exposure_category"
#    [14] "amount_of_alcohol_consumption_per_day"
#    [15] "anatomic_neoplasm_subdivision"
#    [16] "anatomic_neoplasm_subdivision_other"
#    [17] "b_symptoms"
#    [18] "bcr"
#    [19] "bcr_aliquot_uuid"
#    [20] "bcr_canonical_reason-2"
#    [21] "bcr_canonical_reason-3"
#    [22] "bcr_canonical_reason"
#    [23] "bcr_followup_barcode"
#    [24] "bcr_followup_uuid"
#    [25] "bcr_patient_canonical_status"
#    [26] "clinical_m"
#    [27] "clinical_n"
#    [28] "clinical_stage"
#    [29] "clinical_t"
#    [30] "course_number"
#    [31] "day_of_dcc_upload"
# ...

# %% [markdown]
# # Saving gct file to csv file format

# %%
write.csv(data, file = "my_data.csv")
